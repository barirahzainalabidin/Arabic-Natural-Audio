# %%
# %%time

# !pip install openai-whisper
# Out:
# Collecting openai-whisper
#   Downloading openai-whisper-20240930.tar.gz (800 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 800.5/800.5 kB 3.6 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numba in /opt/conda/lib/python3.10/site-packages (from openai-whisper) (0.60.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from openai-whisper) (1.26.4)
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (from openai-whisper) (2.4.0+cpu)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from openai-whisper) (4.66.4)
# Requirement already satisfied: more-itertools in /opt/conda/lib/python3.10/site-packages (from openai-whisper) (10.3.0)
# Collecting tiktoken (from openai-whisper)
#   Downloading tiktoken-0.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting triton>=2.0.0 (from openai-whisper)
#   Downloading triton-3.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.3 kB)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from triton>=2.0.0->openai-whisper) (3.15.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /opt/conda/lib/python3.10/site-packages (from numba->openai-whisper) (0.43.0)
# Requirement already satisfied: regex>=2022.1.18 in /opt/conda/lib/python3.10/site-packages (from tiktoken->openai-whisper) (2024.5.15)
# Requirement already satisfied: requests>=2.26.0 in /opt/conda/lib/python3.10/site-packages (from tiktoken->openai-whisper) (2.32.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch->openai-whisper) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch->openai-whisper) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch->openai-whisper) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch->openai-whisper) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch->openai-whisper) (2024.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken->openai-whisper) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken->openai-whisper) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken->openai-whisper) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken->openai-whisper) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch->openai-whisper) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch->openai-whisper) (1.3.0)
# Downloading triton-3.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (209.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.4/209.4 MB 6.1 MB/s eta 0:00:00:00:0100:01
# Downloading tiktoken-0.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 38.6 MB/s eta 0:00:00
# Building wheels for collected packages: openai-whisper
#   Building wheel for openai-whisper (pyproject.toml) ... done
#   Created wheel for openai-whisper: filename=openai_whisper-20240930-py3-none-any.whl size=803321 sha256=8d5b61aab98645592f9f595345d01c65ea82c6e1f52ed1b4717a203d43d075c5
#   Stored in directory: /root/.cache/pip/wheels/dd/4a/1f/d1c4bf3b9133c8168fe617ed979cab7b14fe381d059ffb9d83
# Successfully built openai-whisper
# Installing collected packages: triton, tiktoken, openai-whisper
# Successfully installed openai-whisper-20240930 tiktoken-0.8.0 triton-3.0.0
# CPU times: user 1.11 s, sys: 232 ms, total: 1.34 s
# Wall time: 43 s

# %%
# %%time

# !pip install openai-whisper googletrans==4.0.0-rc1
# Out:
# Requirement already satisfied: openai-whisper in /opt/conda/lib/python3.10/site-packages (20240930)
# Collecting googletrans==4.0.0-rc1
#   Downloading googletrans-4.0.0rc1.tar.gz (20 kB)
#   Preparing metadata (setup.py) ... done
# Collecting httpx==0.13.3 (from googletrans==4.0.0-rc1)
#   Downloading httpx-0.13.3-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2024.8.30)
# Collecting hstspreload (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading hstspreload-2024.10.1-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.10/site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.3.1)
# Collecting chardet==3.* (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading chardet-3.0.4-py2.py3-none-any.whl.metadata (3.2 kB)
# Collecting idna==2.* (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading idna-2.10-py2.py3-none-any.whl.metadata (9.1 kB)
# Collecting rfc3986<2,>=1.3 (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting httpcore==0.9.* (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading httpcore-0.9.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting h11<0.10,>=0.8 (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading h11-0.9.0-py2.py3-none-any.whl.metadata (8.1 kB)
# Collecting h2==3.* (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading h2-3.2.0-py2.py3-none-any.whl.metadata (32 kB)
# Collecting hyperframe<6,>=5.2.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading hyperframe-5.2.0-py2.py3-none-any.whl.metadata (7.2 kB)
# Collecting hpack<4,>=3.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading hpack-3.0.0-py2.py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: numba in /opt/conda/lib/python3.10/site-packages (from openai-whisper) (0.60.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from openai-whisper) (1.26.4)
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (from openai-whisper) (2.4.0+cpu)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from openai-whisper) (4.66.4)
# Requirement already satisfied: more-itertools in /opt/conda/lib/python3.10/site-packages (from openai-whisper) (10.3.0)
# Requirement already satisfied: tiktoken in /opt/conda/lib/python3.10/site-packages (from openai-whisper) (0.8.0)
# Requirement already satisfied: triton>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from openai-whisper) (3.0.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from triton>=2.0.0->openai-whisper) (3.15.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /opt/conda/lib/python3.10/site-packages (from numba->openai-whisper) (0.43.0)
# Requirement already satisfied: regex>=2022.1.18 in /opt/conda/lib/python3.10/site-packages (from tiktoken->openai-whisper) (2024.5.15)
# Requirement already satisfied: requests>=2.26.0 in /opt/conda/lib/python3.10/site-packages (from tiktoken->openai-whisper) (2.32.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch->openai-whisper) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch->openai-whisper) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch->openai-whisper) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch->openai-whisper) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch->openai-whisper) (2024.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken->openai-whisper) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken->openai-whisper) (1.26.18)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch->openai-whisper) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch->openai-whisper) (1.3.0)
# Downloading httpx-0.13.3-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 1.8 MB/s eta 0:00:00
# Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 2.1 MB/s eta 0:00:00 0:00:01
# Downloading httpcore-0.9.1-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 1.9 MB/s eta 0:00:00
# Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 3.0 MB/s eta 0:00:00
# Downloading h2-3.2.0-py2.py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 3.0 MB/s eta 0:00:00
# Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Downloading hstspreload-2024.10.1-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 11.0 MB/s eta 0:00:0000:0100:01
# Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 2.9 MB/s eta 0:00:00
# Downloading hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Downloading hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17395 sha256=1112c2b51e45e614c3f13619d0a1c36df2201d6db1898536b61fe49cec8f87df
#   Stored in directory: /root/.cache/pip/wheels/c0/59/9f/7372f0cf70160fe61b528532e1a7c8498c4becd6bcffb022de
# Successfully built googletrans
# Installing collected packages: rfc3986, hyperframe, hpack, h11, chardet, idna, hstspreload, h2, httpcore, httpx, googletrans
#   Attempting uninstall: h11
#     Found existing installation: h11 0.14.0
#     Uninstalling h11-0.14.0:
#       Successfully uninstalled h11-0.14.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.7
#     Uninstalling idna-3.7:
#       Successfully uninstalled idna-3.7
#   Attempting uninstall: httpcore
#     Found existing installation: httpcore 1.0.5
#     Uninstalling httpcore-1.0.5:
#       Successfully uninstalled httpcore-1.0.5
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.27.0
#     Uninstalling httpx-0.27.0:
#       Successfully uninstalled httpx-0.27.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastapi 0.111.0 requires httpx>=0.23.0, but you have httpx 0.13.3 which is incompatible.
# jupyterlab 4.2.5 requires httpx>=0.25.0, but you have httpx 0.13.3 which is incompatible.
# jupyterlab 4.2.5 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-lsp 5.1.0 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# ydata-profiling 4.10.0 requires scipy<1.14,>=1.4.1, but you have scipy 1.14.1 which is incompatible.
# Successfully installed chardet-3.0.4 googletrans-4.0.0rc1 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2024.10.1 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 idna-2.10 rfc3986-1.5.0
# CPU times: user 563 ms, sys: 112 ms, total: 675 ms
# Wall time: 21.8 s

# %%
# %%time

import warnings
warnings.filterwarnings('ignore')
# Out:
# CPU times: user 55 µs, sys: 12 µs, total: 67 µs
# Wall time: 72.5 µs

# %%
# %%time

import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt
from scipy.io.wavfile import write
import os

# Load the audio file
audio_file_path = "/kaggle/input/arabic-natural-audio-dataset/V6.wav"

# Replace with the path to your audio file
y, sr = librosa.load(audio_file_path)

# Display the original spectrogram
D_original = librosa.amplitude_to_db(np.abs(librosa.stft(y)), ref=np.max)
plt.figure(figsize=(12, 8))
librosa.display.specshow(D_original, sr=sr, x_axis='time', y_axis='log')
plt.colorbar(format='%+2.0f dB')
plt.title('Original Spectrogram')
plt.show()

# Apply background noise removal
y_harmonic, y_percussive = librosa.effects.hpss(y)
y_noise_removed = y - y_harmonic

# Display the spectrogram after background noise removal
D_noise_removed = librosa.amplitude_to_db(np.abs(librosa.stft(y_noise_removed)), ref=np.max)
plt.figure(figsize=(12, 8))
librosa.display.specshow(D_noise_removed, sr=sr, x_axis='time', y_axis='log')
plt.colorbar(format='%+2.0f dB')
plt.title('Spectrogram after Background Noise Removal')
plt.show()
# Out:
# CPU times: user 49.6 s, sys: 4.63 s, total: 54.3 s
# Wall time: 57.3 s

# %%
# %%time

import whisper

# Load the Whisper model
model = whisper.load_model('base')

# Load and transcribe the audio file
audio_file = y_noise_removed
text = model.transcribe(audio_file)

# Print the transcribed text
text['text']
# Out:
# 100%|███████████████████████████████████████| 139M/139M [00:10<00:00, 13.2MiB/s]
# CPU times: user 5min 54s, sys: 3.26 s, total: 5min 57s
# Wall time: 3min 13s
# ' Alice k cooken jaren die hele keer cheap in Kankolccalled kr leads απ het m eenХl dozens Die daar herde, jaren en jahsen gouszum regimes cursal kijk bar kan een aaha aan Wat weet je voor En we hebben een overdacht voorzokers op water. We hebben een verkefaar voorzude aan iederingen voorzude. Ieder? Ik heb een verkefaar iederingen voorzude aan iederingen voorzude. Ik heb een verkefaar iederingen voorzude. Sam? Hebben er geen moeders wattentijer in uit WAADTкаar met 38 1999 op water! De多f tv is Tiw interactive van eightie inderdaad om het v母 ter wat voorzong van einen. Im de latnis heeft iemand hem weg op kofie, compliant voor de waferen, En dan moet we gaan naar de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de k van de kijkers van de kijkers van de kijkers van de kijk sisters van de kijkers vanuit de kijkers vanuit de kijkers vanuit de kijkers vanuit de kijkers vanuit de suddenly pondigers van de lạ condo dus van het summitje st Row war down van de kijkere van de kijkers van het summitje st Row war dans de��ge met aún die deından shifted van het enur intended van de lucht van de lucht van melodie en van levendood of het spanier dan een jaar g warum netpen van de Egyptians van hetening strongly Ik heb een keer... Att recalled charming falling...'

# %%
# %%time

print(text)
# Out:
# {'text': ' Alice k cooken jaren die hele keer cheap in Kankolccalled kr leads απ het m eenХl dozens Die daar herde, jaren en jahsen gouszum regimes cursal kijk bar kan een aaha aan Wat weet je voor En we hebben een overdacht voorzokers op water. We hebben een verkefaar voorzude aan iederingen voorzude. Ieder? Ik heb een verkefaar iederingen voorzude aan iederingen voorzude. Ik heb een verkefaar iederingen voorzude. Sam? Hebben er geen moeders wattentijer in uit WAADTкаar met 38 1999 op water! De多f tv is Tiw interactive van eightie inderdaad om het v母 ter wat voorzong van einen. Im de latnis heeft iemand hem weg op kofie, compliant voor de waferen, En dan moet we gaan naar de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de kijkers van de k van de kijkers van de kijkers van de kijkers van de kijk sisters van de kijkers vanuit de kijkers vanuit de kijkers vanuit de kijkers vanuit de kijkers vanuit de suddenly pondigers van de lạ condo dus van het summitje st Row war down van de kijkere van de kijkers van het summitje st Row war dans de��ge met aún die deından shifted van het enur intended van de lucht van de lucht van melodie en van levendood of het spanier dan een jaar g warum netpen van de Egyptians van hetening strongly Ik heb een keer... Att recalled charming falling...', 'segments': [{'id': 0, 'seek': 3000, 'start': 30.0, 'end': 32.36, 'text': ' Alice k cooken jaren die hele keer', 'tokens': [50364, 16004, 350, 2543, 268, 361, 4484, 978, 16812, 31531, 50482], 'temperature': 1.0, 'avg_logprob': -5.613054302376761, 'compression_ratio': 1.2255639097744362, 'no_speech_prob': 0.19671081006526947}, {'id': 1, 'seek': 3000, 'start': 32.36, 'end': 33.56, 'text': ' cheap in Kankolccalled kr leads απ het m', 'tokens': [50482, 7084, 294, 11120, 36620, 66, 11880, 15913, 6689, 45787, 3639, 275, 50542], 'temperature': 1.0, 'avg_logprob': -5.613054302376761, 'compression_ratio': 1.2255639097744362, 'no_speech_prob': 0.19671081006526947}, {'id': 2, 'seek': 3000, 'start': 33.56, 'end': 36.0, 'text': ' eenХl dozens', 'tokens': [50542, 3881, 24665, 75, 18431, 50664], 'temperature': 1.0, 'avg_logprob': -5.613054302376761, 'compression_ratio': 1.2255639097744362, 'no_speech_prob': 0.19671081006526947}, {'id': 3, 'seek': 3000, 'start': 37.0, 'end': 39.0, 'text': ' Die daar herde, jaren en jahsen', 'tokens': [50714, 3229, 12390, 720, 1479, 11, 361, 4484, 465, 361, 545, 6748, 50814], 'temperature': 1.0, 'avg_logprob': -5.613054302376761, 'compression_ratio': 1.2255639097744362, 'no_speech_prob': 0.19671081006526947}, {'id': 4, 'seek': 3000, 'start': 39.38, 'end': 40.86, 'text': ' gouszum', 'tokens': [50833, 290, 563, 89, 449, 50907], 'temperature': 1.0, 'avg_logprob': -5.613054302376761, 'compression_ratio': 1.2255639097744362, 'no_speech_prob': 0.19671081006526947}, {'id': 5, 'seek': 3000, 'start': 43.2, 'end': 44.2, 'text': ' regimes', 'tokens': [51024, 45738, 51074], 'temperature': 1.0, 'avg_logprob': -5.613054302376761, 'compression_ratio': 1.2255639097744362, 'no_speech_prob': 0.19671081006526947}, {'id': 6, 'seek': 3000, 'start': 44.22, 'end': 47.24, 'text': ' cursal', 'tokens': [51075, 13946, 304, 51226], 'temperature': 1.0, 'avg_logprob': -5.613054302376761, 'compression_ratio': 1.2255639097744362, 'no_speech_prob': 0.19671081006526947}, {'id': 7, 'seek': 3000, 'start': 48.96, 'end': 50.16, 'text': ' kijk', 'tokens': [51312, 350, 6940, 51372], 'temperature': 1.0, 'avg_lo ...
# CPU times: user 1.61 ms, sys: 0 ns, total: 1.61 ms
# Wall time: 618 µs

# %%
# %%time

result = model.transcribe(audio_file, language='ar')
# Out:
# CPU times: user 7min 23s, sys: 2.14 s, total: 7min 25s
# Wall time: 3min 43s

# %%
# %%time

result
# Out:
# CPU times: user 5 µs, sys: 0 ns, total: 5 µs
# Wall time: 8.58 µs
# {'text': ' لقد أمامتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك اكال البيضة أن يحوشكر aren LAUGH differentiation usage coined the provide language and language called how to carry分享 the provide language with the differences between the differences between the differences between the differences between the differences between the differences between the differences between the differences between the differences between the differences between the differences between the differences between the differences between the differences between the differences between the differences between the difference between the difference between the difference between the differences between the differences between the differences between the differences between the difference between the difference between the difference between the difference between the differences between the differences between the differences between the difference between the changes between the differences between the differences between the differences between the difference between the difference between the difference between the difference between the difference between the differences between the difference between the differences between the difference between the differences between the difference between the difference between the differences between the difference between the difference between the differences between the difference between the difference between the difference between the differences between the differences between the difference between the difference between the differences between how to�도щ that Vietnamese face puree and global Samsung with وصلت إلى سمرة بي مكتب من الأن في كفى أبو جودة عن إداري موجودة في جيد ممتسم الامر На القادر أي مجال في فصBCpse Elizabethizo س連اثة قصتب الأمسي في الن poser الورار مع هذا المخاص إن كان獨ة أضيذ نفسة رك życie للا يحدثوا أن نعف過 الساρة يضر ت bit فقط كر على لنقول إن كان memory أنت كان إن ؟ يَ quarters على تلا أما أن niżول يجب معfang نترجم أولتك من حبيقه أعطيك ربماً أعطيك ربماً أعطيك ربماً سنطلق إن تخيصتك كلمات للمبنة للمبنة سنو وليل واركي وقرنك أن تنمونك إن تتخيصتك إن تتخيصتك للمبنة سنو أعطيك ربماً أعطيك أعطيك أعطيك و يعملقي تسيب Kansas حب و مين منتي أناها رابنا أما نحن في مledفن قلك ميشذ التدار ال лет مع مظ calls العشي لادتظر جموعة من الم Dabei تن Rahmen המשетров على مامоры ففاث الم groundbreaking فيما سฦول في المطاع في المطاع unlimited organizations وأشفك ل apex grilled وبzes سو Aa سوое geç على Airlبان الع MARY حسناها في الكلاس في البطاع أو الله لاinto cácطاع',
#  'segments': [{'id': 0,
#    'seek': 0,
#    'start': 0.0,
#    'end': 30.0,
#    'text': ' لقد أمامتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك لأجابتك',
#    'tokens': [50364,
#     5296,
#     28543,
#     5551,
#     2304,
#     10943,
#     2655,
#     4117,
#     5296,
#     10721,
#     7435,
#     16758,
#     2655,
#     4117,
#     5296,
#     10721,
#     7435,
#     16758,
#     2655,
#     4117,
#     5296,
#     10721,
#     7435,
#     16758,
#     2655,
#     4117,
#     5296,
#     10721,
#     7435,
#     16758,
#     2655,
#     4117,
#     5296,
#     10721,
#     7435,
#     16758,
#     2655,
#     4117,
#     5296,
#     10721,
#     7435,
#     16758,
#     2655,
#     4117,
#     5296,
#     10721,
#     7435,
#     16758,
#     2655,
#     4117,
#     5296,
#     10721,
#     7435,
#     16758,
#     2655,
#     4117,
#     5296,
#     10721,
#     7435,
#     16758,
#     2655,
#     4117,
#     5296,
#     10721,
#     7435,
#     16758,
#     2655,
#     4117,
#     5296,
#     10721,
#     7435,
#     16758,
#     2655,
#     4117,
#     5296,
#     10721,
#     7435,
#     16758,
#     2655,
#     4117,
#     5296,
#     10721,
#     7435,
#     16758,
#     2655,
#     4117,
#     5296,
#     10721,
#     7435,
#     16758,
#     2655,
#     4117,
#     5296,
#     10721,
#     7435,
#     16758,
#     2655,
#     4117,
#     5296,
#     10721,
#     7435,
#     16758,
#     2655,
#     4117,
#     5296,
#     10721,
#     7435,
#     16758,
#     2655,
#     4117,
#     5296,
#     10721,
#     7435,
#     16758,
#     2655,
#     4117,
#     5296,
#     10721,
#     7435,
#     16758,
#     2655,
#     4117,
#     5296,
#     10721,
#     7435,
#     16758,
#     2655,
#     4117,
#     5296,
#     10721,
#     7435,
#     16758,
#     2655,
#     4117,
#     5296,
#     10721,
#     7435,
#     16758,
#     2655,
#     4117,
#     5296,
#     10721,
#     7435,
#     16758,
#     2655,
#     4117,
#     5296,
#     10721,
#     7435,
#     16758,
#     2655,
#     4117,
#     5296,
#     10721,
#     7435,
#     16758,
#     2655,
#     4117,
#     5296,
#     10721,
#     7435,
#     16758,
#     2655,
#     4117,
#     5296,
#     10721,
#     7435,
#     16758,
#     2655,
#     4117,
#     5296,
#     10721,
#     7435,
#     16758,
#     2655,
#     4117,
#     5296,
#     10721,
#     7435,
#     16758,
#     2655,
#     4117,
#     5296,
#     10721,
#     7435,
#     16758,
#     2655,
#     4117,
#     5296,
#     10721,
#     7435,
#     16758,
#     2655,
#     4117,
#     5296,
#     10721,
#     7435,
#     16758,
#     2655,
#     4117,
#     5296,
#     10721,
#     7435,
#     16758,
#     2655,
#     4117,
#     5296,
#     10721,
#     7435,
#     16758,
#     2655,
#     4117,
#     5296,
#     10721,
#     7435,
#     16758,
#     2655,
#     4117,
#     5296,
#     10721,
#     7435,
#     16758,
#     2655,
#     4117],
#    'temperature': 0.0,
#    'avg_logprob': -0.2118816630045573,
#    'compression_ratio': 12.704545454545455,
#    'no_speech_prob': 0.6615824699401855},
#   {'id': 1,
#    'seek': 3000,
#    'start': 30.0,
#    'end': 60.0,
#    'text': ' اكال البيضة أن يحوشكر aren LAUGH differentiation usage coined the provide language and language called how to carry分享 the provide language with the differences between the differences between the differences between the differences between the differences between the differences between the differences between the differences between the differences between the differences between the differences between the differences between the differences between the differences between the differences between the differences between the difference between the difference between the difference between the differences between the differences between the differences between the differences between the difference between the difference between the difference between the difference between the differences between the differences between the differences between the difference between the changes between the differences between the differences between the differences between the difference between the difference between the difference between the difference between the difference between the differences between the difference between the differences between the difference between the differences between the difference between the difference between the differences between the difference between the difference between the differences between the difference between the difference between the difference between the differences between the differences between the difference between the difference between the differences between how to�도щ that Vietnamese face puree and global Samsung with',
#    'tokens': [50364,
#     1975,
#     4117,
#     6027,
#     2423,
#     21292,
#     11242,
#     3660,
#     14739,
#     7251,
#     5016,
#     2407,
#     8592,
#     37983,
#     3212,
#     26355,
#     38902,
#     14924,
#     45222,
#     264,
#     2893,
#     2856,
#     293,
#     2856,
#     1219,
#     577,
#     281,
#     3985,
#     30855,
#     264,
#     2893,
#     2856,
#     365,
#     264,
#     7300,
#     1296,
#     264,
#     7300,
#     1296,
#     264,
#     7300,
#     1296,
#     264,
#     7300,
#     1296,
#     264,
#     7300,
#     1296,
#     264,
#     7300,
#     1296,
#     264,
#     7300,
#     1296,
#     264,
#     7300,
#     1296,
#     264,
#     7300,
#     1296,
#     264,
#     7300,
#     1296,
#     264,
#     7300,
#     1296,
#     264,
#     7300,
#     1296,
#     264,
#     7300,
#     1296,
#     264,
#     7300,
#     1296,
#     264,
#     7300,
#     1296,
#     264,
#     7300,
#     1296,
#     264,
#     2649,
#     1296,
#     264,
#     2649,
#     1296,
#     264,
#     2649,
#     1296,
#     264,
#     7300,
#     1296,
#     264,
#     7300,
#     1296,
#     264,
#     7300,
#     1296,
#     264,
#     7300,
#     1296,
#     264,
#     2649,
#     1296,
#     264,
#     2649,
#     1296,
#     264,
#     2649,
#     1296,
#     264,
#     2649,
#     1296,
#     264,
#     7300,
#     1296,
#     264,
#     7300,
#     1296,
#     264,
#     7300,
#     1296,
#     264,
#     2649,
#     1296,
#     264,
#     2962,
#     1296,
#     264,
#     7300,
#     1296,
#     264,
#     7300,
#     1296,
#     264,
#     7300,
#     1296,
#     264,
#     2649,
#     1296,
#     264,
#     2649,
#     1296,
#     264,
#     2649,
#     1296,
#     264,
#     2649,
#     1296,
#     264,
#     2649,
#     1296,
#     264,
#     7300,
#     1296,
#     264,
#     2649,
#     1296,
#     264,
#     7300,
#     1296,
#     264,
#     2649,
#     1296,
#     264,
#     7300,
#     1296,
#     264,
#     2649,
#     1296,
#     264,
#     2649,
#     1296,
#     264,
#     7300,
#     1296,
#     264,
#     2649,
#     1296,
#     264,
#     2649,
#     1296,
#     264,
#     7300,
#     1296,
#     264,
#     2649,
#     1296,
#     264,
#     2649,
#     1296,
#     264,
#     2649,
#     1296,
#     264,
#     7300,
#     1296,
#     264,
#     7300,
#     1296,
#     264,
#     2649,
#     1296,
#     264,
#     2649,
#     1296,
#     264,
#     7300,
#     1296,
#     577,
#     281,
#     33225,
#     2000,
#     300,
#     25934,
#     1851,
#     49407,
#     293,
#     4338,
#     13173,
#     365],
#    'temperature': 1.0,
#    'avg_logprob': -1.5216115087671664,
#    'compression_ratio': 6.745833333333334,
#    'no_speech_prob': 0.48300573229789734},
#   {'id': 2,
#    'seek': 12000,
#    'start': 120.0,
#    'end': 127.0,
#    'text': ' وصلت إلى سمرة بي مكتب من الأن في كفى أبو جودة عن إداري موجودة',
#    'tokens': [50364,
#     4032,
#     36520,
#     2655,
#     30731,
#     8608,
#     2304,
#     25720,
#     4724,
#     1829,
#     3714,
#     4117,
#     2655,
#     3555,
#     9154,
#     16247,
#     1863,
#     8978,
#     9122,
#     5172,
#     7578,
#     5551,
#     3555,
#     2407,
#     10874,
#     23328,
#     3660,
#     18871,
#     11933,
#     3215,
#     9640,
#     1829,
#     3714,
#     29245,
#     23328,
#     3660,
#     50714],
#    'temperature': 0.0,
#    'avg_logprob': -0.3530930582682292,
#    'compression_ratio': 6.622641509433962,
#    'no_speech_prob': 0.6135343909263611},
#   {'id': 3,
#    'seek': 12000,
#    'start': 127.0,
#    'end': 128.5,
#    'text': ' في جيد',
#    'tokens': [50714, 8978, 10874, 25708, 50789],
#    'temperature': 0.0,
#    'avg_logprob': -0.3530930582682292,
#    'compression_ratio': 6.622641509433962,
#    'no_speech_prob': 0.6135343909263611},
#   {'id': 4,
#    'seek': 12850,
#    'start': 128.5,
#    'end': 132.5,
#    'text': ' ممتسم الامر',
#    'tokens': [50364, 3714, 2304, 2655, 38251, 2423, 10943, 2288, 50564],
#    'temperature': 1.0,
#    'avg_logprob': -4.652581787109375,
#    'compression_ratio': 1.0,
#    'no_speech_prob': 0.04134692996740341},
#   {'id': 5,
#    'seek': 12850,
#    'start': 133.5,
#    'end': 136.92,
#    'text': ' На القادر',
#    'tokens': [50614, 11245, 25062, 18513, 2288, 50785],
#    'temperature': 1.0,
#    'avg_logprob': -4.652581787109375,
#    'compression_ratio': 1.0,
#    'no_speech_prob': 0.04134692996740341},
#   {'id': 6,
#    'seek': 12850,
#    'start': 137.5,
#    'end': 139.5,
#    'text': ' أي مجال',
#    'tokens': [50814, 36632, 3714, 7435, 6027, 50914],
#    'temperature': 1.0,
#    'avg_logprob': -4.652581787109375,
#    'compression_ratio': 1.0,
#    'no_speech_prob': 0.04134692996740341},
#   {'id': 7,
#    'seek': 12850,
#    'start': 139.5,
#    'end': 142.5,
#    'text': ' في فصBC',
#    'tokens': [50914, 8978, 6156, 9381, 7869, 51064],
#    'temperature': 1.0,
#    'avg_logprob': -4.652581787109375,
#    'compression_ratio': 1.0,
#    'no_speech_prob': 0.04134692996740341},
#   {'id': 8,
#    'seek': 12850,
#    'start': 152.5,
#    'end': 154.5,
#    'text': 'pse Elizabeth',
#    'tokens': [51564, 17738, 12978, 51664],
#    'temperature': 1.0,
#    'avg_logprob': -4.652581787109375,
#    'compression_ratio': 1.0,
#    'no_speech_prob': 0.04134692996740341},
#   {'id': 9,
#    'seek': 12850,
#    'start': 157.5,
#    'end': 158.5,
#    'text': 'izo',
#    'tokens': [51814, 19055, 51864],
#    'temperature': 1.0,
#    'avg_logprob': -4.652581787109375,
#    'compression_ratio': 1.0,
#    'no_speech_prob': 0.04134692996740341},
#   {'id': 10,
#    'seek': 15850,
#    'start': 159.34,
#    'end': 161.86,
#    'text': ' س連اثة قصتب الأمسي',
#    'tokens': [50406,
#     8608,
#     36252,
#     5718,
#     104,
#     3660,
#     12174,
#     9381,
#     2655,
#     3555,
#     16247,
#     2304,
#     3794,
#     1829,
#     50532],
#    'temperature': 1.0,
#    'avg_logprob': -4.324332166073927,
#    'compression_ratio': 1.4197530864197532,
#    'no_speech_prob': 0.5872071385383606},
#   {'id': 11,
#    'seek': 15850,
#    'start': 162.9,
#    'end': 164.14,
#    'text': ' في الن poser الورار',
#    'tokens': [50584, 8978, 28239, 39355, 2423, 2407, 2288, 9640, 50646],
#    'temperature': 1.0,
#    'avg_logprob': -4.324332166073927,
#    'compression_ratio': 1.4197530864197532,
#    'no_speech_prob': 0.5872071385383606},
#   {'id': 12,
#    'seek': 15850,
#    'start': 164.14,
#    'end': 165.78,
#    'text': ' مع هذا المخاص',
#    'tokens': [50646, 20449, 23758, 9673, 9778, 33546, 50728],
#    'temperature': 1.0,
#    'avg_logprob': -4.324332166073927,
#    'compression_ratio': 1.4197530864197532,
#    'no_speech_prob': 0.5872071385383606},
#   {'id': 13,
#    'seek': 15850,
#    'start': 165.78,
#    'end': 167.46,
#    'text': ' إن كان獨ة أضيذ نفسة',
#    'tokens': [50728,
#     36145,
#     25961,
#     163,
#     18304,
#     3660,
#     5551,
#     11242,
#     1829,
#     8848,
#     8717,
#     36178,
#     3660,
#     50812],
#    'temperature': 1.0,
#    'avg_logprob': -4.324332166073927,
#    'compression_ratio': 1.4197530864197532,
#    'no_speech_prob': 0.5872071385383606},
#   {'id': 14,
#    'seek': 15850,
#    'start': 167.46,
#    'end': 168.0,
#    'text': ' رك życie',
#    'tokens': [50812, 12602, 4117, 43202, 50839],
#    'temperature': 1.0,
#    'avg_logprob': -4.324332166073927,
#    'compression_ratio': 1.4197530864197532,
#    'no_speech_prob': 0.5872071385383606},
#   {'id': 15,
#    'seek': 15850,
#    'start': 168.0,
#    'end': 168.82,
#    'text': ' للا يحدثوا',
#    'tokens': [50839, 5296, 15040, 7251, 24401, 12984, 14407, 50880],
#    'temperature': 1.0,
#    'avg_logprob': -4.324332166073927,
#    'compression_ratio': 1.4197530864197532,
#    'no_speech_prob': 0.5872071385383606},
#   {'id': 16,
#    'seek': 15850,
#    'start': 168.82,
#    'end': 169.48,
#    'text': ' أن نعف過',
#    'tokens': [50880, 14739, 8717, 3615, 5172, 8816, 50913],
#    'temperature': 1.0,
#    'avg_logprob': -4.324332166073927,
#    'compression_ratio': 1.4197530864197532,
#    'no_speech_prob': 0.5872071385383606},
#   {'id': 17,
#    'seek': 15850,
#    'start': 169.48,
#    'end': 170.34,
#    'text': ' الساρة',
#    'tokens': [50913, 21136, 995, 2805, 3660, 50956],
#    'temperature': 1.0,
#    'avg_logprob': -4.324332166073927,
#    'compression_ratio': 1.4197530864197532,
#    'no_speech_prob': 0.5872071385383606},
#   {'id': 18,
#    'seek': 15850,
#    'start': 171.82,
#    'end': 172.72,
#    'text': ' يضر ت bit',
#    'tokens': [51030, 7251, 11242, 2288, 6055, 857, 51075],
#    'temperature': 1.0,
#    'avg_logprob': -4.324332166073927,
#    'compression_ratio': 1.4197530864197532,
#    'no_speech_prob': 0.5872071385383606},
#   {'id': 19,
#    'seek': 15850,
#    'start': 172.72,
#    'end': 173.76,
#    'text': ' فقط',
#    'tokens': [51075, 6156, 47432, 51127],
#    'temperature': 1.0,
#    'avg_logprob': -4.324332166073927,
#    'compression_ratio': 1.4197530864197532,
#    'no_speech_prob': 0.5872071385383606},
#   {'id': 20,
#    'seek': 15850,
#    'start': 173.76,
#    'end': 174.76,
#    'text': ' كر على',
#    'tokens': [51127, 9122, 2288, 15844, 51177],
#    'temperature': 1.0,
#    'avg_logprob': -4.324332166073927,
#    'compression_ratio': 1.4197530864197532,
#    'no_speech_prob': 0.5872071385383606},
#   {'id': 21,
#    'seek': 15850,
#    'start': 174.9,
#    'end': 176.0,
#    'text': ' لنقول',
#    'tokens': [51184, 5296, 1863, 39648, 51239],
#    'temperature': 1.0,
#    'avg_logprob': -4.324332166073927,
#    'compression_ratio': 1.4197530864197532,
#    'no_speech_prob': 0.5872071385383606},
#   {'id': 22,
#    'seek': 15850,
#    'start': 176.0,
#    'end': 177.24,
#    'text': ' إن كان memory',
#    'tokens': [51239, 36145, 25961, 4675, 51301],
#    'temperature': 1.0,
#    'avg_logprob': -4.324332166073927,
#    'compression_ratio': 1.4197530864197532,
#    'no_speech_prob': 0.5872071385383606},
#   {'id': 23,
#    'seek': 15850,
#    'start': 177.62,
#    'end': 179.0,
#    'text': ' أنت كان إن ؟',
#    'tokens': [51320, 14739, 2655, 25961, 36145, 45520, 51389],
#    'temperature': 1.0,
#    'avg_logprob': -4.324332166073927,
#    'compression_ratio': 1.4197530864197532,
#    'no_speech_prob': 0.5872071385383606},
#   {'id': 24,
#    'seek': 15850,
#    'start': 179.0,
#    'end': 180.42000000000002,
#    'text': ' يَ quarters على',
#    'tokens': [51389, 7251, 6808, 20612, 15844, 51460],
#    'temperature': 1.0,
#    'avg_logprob': -4.324332166073927,
#    'compression_ratio': 1.4197530864197532,
#    'no_speech_prob': 0.5872071385383606},
#   {'id': 25,
#    'seek': 15850,
#    'start': 181.06,
#    'end': 182.66,
#    'text': ' تلا أما أن niżول',
#    'tokens': [51492, 6055, 15040, 5551, 15042, 14739, 28502, 12610, 51572],
#    'temperature': 1.0,
#    'avg_logprob': -4.324332166073927,
#    'compression_ratio': 1.4197530864197532,
#    'no_speech_prob': 0.5872071385383606},
#   {'id': 26,
#    'seek': 15850,
#    'start': 183.48,
#    'end': 184.84,
#    'text': ' يجب معfang',
#    'tokens': [51613, 7251, 7435, 3555, 20449, 19134, 51681],
#    'temperature': 1.0,
#    'avg_logprob': -4.324332166073927,
#    'compression_ratio': 1.4197530864197532,
#    'no_speech_prob': 0.5872071385383606},
#   {'id': 27,
#    'seek': 15850,
#    'start': 184.96,
#    'end': 186.24,
#    'text': ' نترجم',
#    'tokens': [51687, 8717, 2655, 47341, 2304, 51751],
#    'temperature': 1.0,
#    'avg_logprob': -4.324332166073927,
#    'compression_ratio': 1.4197530864197532,
#    'no_speech_prob': 0.5872071385383606},
#   {'id': 28,
#    'seek': 18624,
#    'start': 186.24,
#    'end': 189.24,
#    'text': ' أولتك من حبيقه',
#    'tokens': [50364,
#     5551,
#     12610,
#     2655,
#     4117,
#     9154,
#     11331,
#     21292,
#     4587,
#     3224,
#     50514],
#    'temperature': 0.0,
#    'avg_logprob': -0.9387548055993505,
#    'compression_ratio': 2.5114503816793894,
#    'no_speech_prob': 0.6029115319252014},
#   {'id': 29,
#    'seek': 18624,
#    'start': 189.24,
#    'end': 192.24,
#    'text': ' أعطيك ربماً',
#    'tokens': [50514,
#     5551,
#     3615,
#     9566,
#     1829,
#     4117,
#     12602,
#     3555,
#     15042,
#     14111,
#     50664],
#    'temperature': 0.0,
#    'avg_logprob': -0.9387548055993505,
#    'compression_ratio': 2.5114503816793894,
#    'no_speech_prob': 0.6029115319252014},
#   {'id': 30,
#    'seek': 18624,
#    'start': 192.24,
#    'end': 194.24,
#    'text': ' أعطيك ربماً',
#    'tokens': [50664,
#     5551,
#     3615,
#     9566,
#     1829,
#     4117,
#     12602,
#     3555,
#     15042,
#     14111,
#     50764],
#    'temperature': 0.0,
#    'avg_logprob': -0.9387548055993505,
#    'compression_ratio': 2.5114503816793894,
#    'no_speech_prob': 0.6029115319252014},
#   {'id': 31,
#    'seek': 18624,
#    'start': 194.24,
#    'end': 196.24,
#    'text': ' أعطيك ربماً',
#    'tokens': [50764,
#     5551,
#     3615,
#     9566,
#     1829,
#     4117,
#     12602,
#     3555,
#     15042,
#     14111,
#     50864],
#    'temperature': 0.0,
#    'avg_logprob': -0.9387548055993505,
#    'compression_ratio': 2.5114503816793894,
#    'no_speech_prob': 0.6029115319252014},
#   {'id': 32,
#    'seek': 18624,
#    'start': 196.24,
#    'end': 197.24,
#    'text': ' سنطلق',
#    'tokens': [50864, 8608, 1863, 9566, 1211, 4587, 50914],
#    'temperature': 0.0,
#    'avg_logprob': -0.9387548055993505,
#    'compression_ratio': 2.5114503816793894,
#    'no_speech_prob': 0.6029115319252014},
#   {'id': 33,
#    'seek': 18624,
#    'start': 197.24,
#    'end': 198.24,
#    'text': ' إن تخيصتك',
#    'tokens': [50914, 36145, 6055, 9778, 1829, 9381, 2655, 4117, 50964],
#    'temperature': 0.0,
#    'avg_logprob': -0.9387548055993505,
#    'compression_ratio': 2.5114503816793894,
#    'no_speech_prob': 0.6029115319252014},
#   {'id': 34,
#    'seek': 18624,
#    'start': 198.24,
#    'end': 199.24,
#    'text': ' كلمات للمبنة',
#    'tokens': [50964, 9122, 19528, 9307, 5296, 19528, 3555, 1863, 3660, 51014],
#    'temperature': 0.0,
#    'avg_logprob': -0.9387548055993505,
#    'compression_ratio': 2.5114503816793894,
#    'no_speech_prob': 0.6029115319252014},
#   {'id': 35,
#    'seek': 18624,
#    'start': 199.24,
#    'end': 201.24,
#    'text': ' للمبنة سنو',
#    'tokens': [51014, 5296, 19528, 3555, 1863, 3660, 8608, 1863, 2407, 51114],
#    'temperature': 0.0,
#    'avg_logprob': -0.9387548055993505,
#    'compression_ratio': 2.5114503816793894,
#    'no_speech_prob': 0.6029115319252014},
#   {'id': 36,
#    'seek': 18624,
#    'start': 201.24,
#    'end': 202.24,
#    'text': ' وليل واركي',
#    'tokens': [51114, 4032, 20292, 1211, 4032, 9640, 4117, 1829, 51164],
#    'temperature': 0.0,
#    'avg_logprob': -0.9387548055993505,
#    'compression_ratio': 2.5114503816793894,
#    'no_speech_prob': 0.6029115319252014},
#   {'id': 37,
#    'seek': 18624,
#    'start': 202.24,
#    'end': 204.24,
#    'text': ' وقرنك أن تنمونك',
#    'tokens': [51164,
#     4032,
#     4587,
#     2288,
#     1863,
#     4117,
#     14739,
#     6055,
#     1863,
#     2304,
#     11536,
#     4117,
#     51264],
#    'temperature': 0.0,
#    'avg_logprob': -0.9387548055993505,
#    'compression_ratio': 2.5114503816793894,
#    'no_speech_prob': 0.6029115319252014},
#   {'id': 38,
#    'seek': 18624,
#    'start': 204.24,
#    'end': 206.24,
#    'text': ' إن تتخيصتك',
#    'tokens': [51264, 36145, 6055, 2655, 9778, 1829, 9381, 2655, 4117, 51364],
#    'temperature': 0.0,
#    'avg_logprob': -0.9387548055993505,
#    'compression_ratio': 2.5114503816793894,
#    'no_speech_prob': 0.6029115319252014},
#   {'id': 39,
#    'seek': 18624,
#    'start': 206.24,
#    'end': 207.24,
#    'text': ' إن تتخيصتك',
#    'tokens': [51364, 36145, 6055, 2655, 9778, 1829, 9381, 2655, 4117, 51414],
#    'temperature': 0.0,
#    'avg_logprob': -0.9387548055993505,
#    'compression_ratio': 2.5114503816793894,
#    'no_speech_prob': 0.6029115319252014},
#   {'id': 40,
#    'seek': 18624,
#    'start': 207.24,
#    'end': 208.24,
#    'text': ' للمبنة سنو',
#    'tokens': [51414, 5296, 19528, 3555, 1863, 3660, 8608, 1863, 2407, 51464],
#    'temperature': 0.0,
#    'avg_logprob': -0.9387548055993505,
#    'compression_ratio': 2.5114503816793894,
#    'no_speech_prob': 0.6029115319252014},
#   {'id': 41,
#    'seek': 18624,
#    'start': 208.24,
#    'end': 209.24,
#    'text': ' أعطيك ربماً',
#    'tokens': [51464,
#     5551,
#     3615,
#     9566,
#     1829,
#     4117,
#     12602,
#     3555,
#     15042,
#     14111,
#     51514],
#    'temperature': 0.0,
#    'avg_logprob': -0.9387548055993505,
#    'compression_ratio': 2.5114503816793894,
#    'no_speech_prob': 0.6029115319252014},
#   {'id': 42,
#    'seek': 18624,
#    'start': 209.24,
#    'end': 210.24,
#    'text': ' أعطيك',
#    'tokens': [51514, 5551, 3615, 9566, 1829, 4117, 51564],
#    'temperature': 0.0,
#    'avg_logprob': -0.9387548055993505,
#    'compression_ratio': 2.5114503816793894,
#    'no_speech_prob': 0.6029115319252014},
#   {'id': 43,
#    'seek': 18624,
#    'start': 210.24,
#    'end': 211.24,
#    'text': ' أعطيك',
#    'tokens': [51564, 5551, 3615, 9566, 1829, 4117, 51614],
#    'temperature': 0.0,
#    'avg_logprob': -0.9387548055993505,
#    'compression_ratio': 2.5114503816793894,
#    'no_speech_prob': 0.6029115319252014},
#   {'id': 44,
#    'seek': 18624,
#    'start': 211.24,
#    'end': 212.24,
#    'text': ' أعطيك',
#    'tokens': [51614, 5551, 3615, 9566, 1829, 4117, 51664],
#    'temperature': 0.0,
#    'avg_logprob': -0.9387548055993505,
#    'compression_ratio': 2.5114503816793894,
#    'no_speech_prob': 0.6029115319252014},
#   {'id': 45,
#    'seek': 21224,
#    'start': 212.24,
#    'end': 215.24,
#    'text': ' و يعملقي تسيب Kansas',
#    'tokens': [50364,
#     4032,
#     7251,
#     25957,
#     1211,
#     38436,
#     6055,
#     3794,
#     1829,
#     3555,
#     19422,
#     50514],
#    'temperature': 1.0,
#    'avg_logprob': -4.0204249019116425,
#    'compression_ratio': 1.3454545454545455,
#    'no_speech_prob': 0.3879868984222412},
#   {'id': 46,
#    'seek': 21224,
#    'start': 215.24,
#    'end': 218.32000000000002,
#    'text': ' حب و مين منتي',
#    'tokens': [50514, 11331, 3555, 4032, 3714, 9957, 9154, 31371, 50668],
#    'temperature': 1.0,
#    'avg_logprob': -4.0204249019116425,
#    'compression_ratio': 1.3454545454545455,
#    'no_speech_prob': 0.3879868984222412},
#   {'id': 47,
#    'seek': 21224,
#    'start': 218.32000000000002,
#    'end': 219.24,
#    'text': ' أناها رابنا',
#    'tokens': [50668, 41850, 11296, 12602, 16758, 8315, 50714],
#    'temperature': 1.0,
#    'avg_logprob': -4.0204249019116425,
#    'compression_ratio': 1.3454545454545455,
#    'no_speech_prob': 0.3879868984222412},
#   {'id': 48,
#    'seek': 21224,
#    'start': 219.24,
#    'end': 221.24,
#    'text': ' أما نحن في مledفن',
#    'tokens': [50714,
#     5551,
#     15042,
#     8717,
#     5016,
#     1863,
#     8978,
#     3714,
#     1493,
#     5172,
#     1863,
#     50814],
#    'temperature': 1.0,
#    'avg_logprob': -4.0204249019116425,
#    'compression_ratio': 1.3454545454545455,
#    'no_speech_prob': 0.3879868984222412},
#   {'id': 49,
#    'seek': 21224,
#    'start': 224.24,
#    'end': 226.24,
#    'text': ' قلك ميشذ',
#    'tokens': [50964, 12174, 1211, 4117, 3714, 1829, 8592, 8848, 51064],
#    'temperature': 1.0,
#    'avg_logprob': -4.0204249019116425,
#    'compression_ratio': 1.3454545454545455,
#    'no_speech_prob': 0.3879868984222412},
#   {'id': 50,
#    'seek': 21224,
#    'start': 226.24,
#    'end': 227.24,
#    'text': ' التدار ال лет',
#    'tokens': [51064, 16712, 3215, 9640, 2423, 13088, 51114],
#    'temperature': 1.0,
#    'avg_logprob': -4.0204249019116425,
#    'compression_ratio': 1.3454545454545455,
#    'no_speech_prob': 0.3879868984222412},
#   {'id': 51,
#    'seek': 21224,
#    'start': 227.24,
#    'end': 228.24,
#    'text': ' مع مظ calls',
#    'tokens': [51114, 20449, 3714, 19913, 5498, 51164],
#    'temperature': 1.0,
#    'avg_logprob': -4.0204249019116425,
#    'compression_ratio': 1.3454545454545455,
#    'no_speech_prob': 0.3879868984222412},
#   {'id': 52,
#    'seek': 21224,
#    'start': 228.24,
#    'end': 229.24,
#    'text': ' العشي',
#    'tokens': [51164, 18863, 8592, 1829, 51214],
#    'temperature': 1.0,
#    'avg_logprob': -4.0204249019116425,
#    'compression_ratio': 1.3454545454545455,
#    'no_speech_prob': 0.3879868984222412},
#   {'id': 53,
#    'seek': 21224,
#    'start': 229.24,
#    'end': 231.26000000000002,
#    'text': ' لادتظر',
#    'tokens': [51214, 5296, 18513, 2655, 19913, 2288, 51315],
#    'temperature': 1.0,
#    'avg_logprob': -4.0204249019116425,
#    'compression_ratio': 1.3454545454545455,
#    'no_speech_prob': 0.3879868984222412},
#   {'id': 54,
#    'seek': 21224,
#    'start': 231.26000000000002,
#    'end': 231.52,
#    'text': ' جموعة من الم Dabei',
#    'tokens': [51315, 10874, 2304, 2407, 27884, 9154, 9673, 39606, 51328],
#    'temperature': 1.0,
#    'avg_logprob': -4.0204249019116425,
#    'compression_ratio': 1.3454545454545455,
#    'no_speech_prob': 0.3879868984222412},
#   {'id': 55,
#    'seek': 21224,
#    'start': 232.24,
#    'end': 234.22,
#    'text': ' تن Rahmen',
#    'tokens': [51364, 6055, 1863, 39070, 51463],
#    'temperature': 1.0,
#    'avg_logprob': -4.0204249019116425,
#    'compression_ratio': 1.3454545454545455,
#    'no_speech_prob': 0.3879868984222412},
#   {'id': 56,
#    'seek': 21224,
#    'start': 234.22,
#    'end': 235.24,
#    'text': ' המשетров',
#    'tokens': [51463, 17270, 102, 35852, 51514],
#    'temperature': 1.0,
#    'avg_logprob': -4.0204249019116425,
#    'compression_ratio': 1.3454545454545455,
#    'no_speech_prob': 0.3879868984222412},
#   {'id': 57,
#    'seek': 21224,
#    'start': 235.24,
#    'end': 237.24,
#    'text': ' على مام',
#    'tokens': [51514, 15844, 3714, 10943, 51614],
#    'temperature': 1.0,
#    'avg_logprob': -4.0204249019116425,
#    'compression_ratio': 1.3454545454545455,
#    'no_speech_prob': 0.3879868984222412},
#   {'id': 58,
#    'seek': 21224,
#    'start': 237.24,
#    'end': 238.20000000000002,
#    'text': 'оры',
#    'tokens': [51614, 42342, 51662],
#    'temperature': 1.0,
#    'avg_logprob': -4.0204249019116425,
#    'compression_ratio': 1.3454545454545455,
#    'no_speech_prob': 0.3879868984222412},
#   {'id': 59,
#    'seek': 21224,
#    'start': 238.20000000000002,
#    'end': 239.24,
#    'text': ' ففاث',
#    'tokens': [51662, 6156, 5172, 5718, 104, 51714],
#    'temperature': 1.0,
#    'avg_logprob': -4.0204249019116425,
#    'compression_ratio': 1.3454545454545455,
#    'no_speech_prob': 0.3879868984222412},
#   {'id': 60,
#    'seek': 21224,
#    'start': 239.24,
#    'end': 241.24,
#    'text': ' الم groundbreaking',
#    'tokens': [51714, 9673, 42491, 51814],
#    'temperature': 1.0,
#    'avg_logprob': -4.0204249019116425,
#    'compression_ratio': 1.3454545454545455,
#    'no_speech_prob': 0.3879868984222412},
#   {'id': 61,
#    'seek': 27124,
#    'start': 271.24,
#    'end': 273.52,
#    'text': ' فيما سฦول',
#    'tokens': [50364, 8978, 15042, 8608, 839, 99, 12610, 50478],
#    'temperature': 1.0,
#    'avg_logprob': -4.764947188527961,
#    'compression_ratio': 1.355191256830601,
#    'no_speech_prob': 0.5601974129676819},
#   {'id': 62,
#    'seek': 27124,
#    'start': 273.72,
#    'end': 275.88,
#    'text': ' في المطاع في المطاع unlimited organizations',
#    'tokens': [50488,
#     8978,
#     9673,
#     9566,
#     45761,
#     8978,
#     9673,
#     9566,
#     45761,
#     21950,
#     6150,
#     50596],
#    'temperature': 1.0,
#    'avg_logprob': -4.764947188527961,
#    'compression_ratio': 1.355191256830601,
#    'no_speech_prob': 0.5601974129676819},
#   {'id': 63,
#    'seek': 27124,
#    'start': 275.88,
#    'end': 278.16,
#    'text': ' وأشفك ل apex grilled',
#    'tokens': [50596, 36725, 8592, 5172, 4117, 5296, 48115, 25183, 50710],
#    'temperature': 1.0,
#    'avg_logprob': -4.764947188527961,
#    'compression_ratio': 1.355191256830601,
#    'no_speech_prob': 0.5601974129676819},
#   {'id': 64,
#    'seek': 27124,
#    'start': 278.86,
#    'end': 281.0,
#    'text': ' وبzes سو Aa',
#    'tokens': [50745, 46599, 12214, 8608, 2407, 21460, 50852],
#    'temperature': 1.0,
#    'avg_logprob': -4.764947188527961,
#    'compression_ratio': 1.355191256830601,
#    'no_speech_prob': 0.5601974129676819},
#   {'id': 65,
#    'seek': 27124,
#    'start': 281.0,
#    'end': 282.78000000000003,
#    'text': ' سوое geç على Airlبان',
#    'tokens': [50852, 8608, 2407, 5805, 13110, 15844, 34421, 3555, 7649, 50941],
#    'temperature': 1.0,
#    'avg_logprob': -4.764947188527961,
#    'compression_ratio': 1.355191256830601,
#    'no_speech_prob': 0.5601974129676819},
#   {'id': 66,
#    'seek': 27124,
#    'start': 282.94,
#    'end': 283.76,
#    'text': ' الع MARY',
#    'tokens': [50949, 18863, 37640, 50990],
#    'temperature': 1.0,
#    'avg_logprob': -4.764947188527961,
#    'compression_ratio': 1.355191256830601,
#    'no_speech_prob': 0.5601974129676819},
#   {'id': 67,
#    'seek': 27124,
#    'start': 284.02,
#    'end': 286.72,
#    'text': ' حسناها في الكلاس في البطاع',
#    'tokens': [51003,
#     11331,
#     3794,
#     8315,
#     11296,
#     8978,
#     33251,
#     15040,
#     3794,
#     8978,
#     29739,
#     9566,
#     45761,
#     51138],
#    'temperature': 1.0,
#    'avg_logprob': -4.764947188527961,
#    'compression_ratio': 1.355191256830601,
#    'no_speech_prob': 0.5601974129676819},
#   {'id': 68,
#    'seek': 27124,
#    'start': 287.2,
#    'end': 288.40000000000003,
#    'text': ' أو الله',
#    'tokens': [51162, 34051, 21984, 51222],
#    'temperature': 1.0,
#    'avg_logprob': -4.764947188527961,
#    'compression_ratio': 1.355191256830601,
#    'no_speech_prob': 0.5601974129676819},
#   {'id': 69,
#    'seek': 27124,
#    'start': 288.40000000000003,
#    'end': 289.82,
#    'text': ' لاinto cácطاع',
#    'tokens': [51222, 20193, 17246, 13250, 9566, 45761, 51293],
#    'temperature': 1.0,
#    'avg_logprob': -4.764947188527961,
#    'compression_ratio': 1.355191256830601,
#    'no_speech_prob': 0.5601974129676819}],
#  'language': 'ar'}

# %%
# %%time

from googletrans import Translator
import whisper

# Load Whisper model
model = whisper.load_model('base')

# Transcribe the audio
audio_file = "/kaggle/input/arabic-natural-audio-dataset/V6.wav"
result = model.transcribe(audio_file)

# Translate the transcribed text into English
transcribed_text = result.get('text')
if transcribed_text:
    translator = Translator()
    translated_result = translator.translate(transcribed_text, dest='en')

# Print the translated text
    print("Translated Text:", translated_result.text)
else:
    print("Error: Transcription result is empty. Cannot proceed with translation.")
# Out:
# Translated Text: And the monopoly of your outlet from King Adir is alive.And you, Gatten, your bad words.Set.Set.Are your lifetime tunnels?Yes.I see the chance of Samour Amir and believed that you have an existing administrative death.You are an administrative death outside in Al -And Andy.And our difference we find us in the graves.I speak to speak to speak to speak.I speak to speak to speak to speak to speak to speak to speak to speak to speak to speak to speak to speak to speak to speak to speak to speak to speak to speak to speak to speak to speak to speak to speak to speak to speak thatI speak to speak to speak to speak to speak to speak to speak to speak to speak to speak to speak to speak to speak to speak to speak to speak to speak to speak to speak that I can speak to speak to speak to speak to speak to speak thatI speak to speak to speak to speak to speak to speak to speak to speak to speak to speak to speak to speak to speak to speak to speak to speak to speak to speak to speak to speak to speak to speak to speak to speak to speak thatI speak to speak to speak to speak to speak to speak to speak to speak to speak to speak to speak to speak to speak to speak that flying to speak to speak to speak to speak to speak to speak that I speak to speak to speak thatI speak to speak to speak to speak to speak to speak to speak that Mipsin is more.Falç d.Falç The Deedict.Falç d.Falç d.Falçtud.There is Mayr Compluch as Alisud Takeer.Abu Bengaf.Peninsula and Booklet is Stars and Mantener.That is the stomach, or you speak the truth, Hani for you, and we change you.Your tears is that in today's match, there is no time for our fateful banana, but not in this way, and this drink that is completely decided, so we allow you to trucks. This is building for youRaki and feel everyone who wishes an explanation and what is an explanation and its matters of all of it.Tanzua for Moumaga
# CPU times: user 3min 16s, sys: 1.83 s, total: 3min 18s
# Wall time: 2min 8s
